# %% [markdown]
# # Problem 2
# In this case we have 10 cities

# %% [markdown]
# Load all the necessary libraries and the algorithm

# %%
import tsplib95
import matplotlib.pyplot as plt
import networkx as nx
import importlib
imported_module = importlib.import_module("tsp_genetic_algorithm")
importlib.reload(imported_module)
from tsp_genetic_algorithm import TSP

# %% [markdown]
# Load the original TSP problem

# %%
original_problem = tsplib95.load('att48.tsp')

# %% [markdown]
# Reduce the problem from 48 to 10 cities

# %%
# Extract node coordinates for the first N cities
N = 10
reduced_nodes = {key: original_problem.node_coords[key] for key in list(original_problem.get_nodes())[:N]}

# Create a new TSP problem with only N cities
reduced_problem = tsplib95.models.StandardProblem(comment="Reduced TSP to " + str(N) + "cities")
reduced_problem.node_coords = reduced_nodes

# %% [markdown]
# Run the algorithm

# %%
tsp = TSP(reduced_problem, 80, 500, 0.1, 0.8, 'rank_selection', 'ordered_crossover', 'swap_mutate')
tsp.run()
# Out:
# Initial fitness:
# 3.8884921678399816e-05
# Fitness generation number 0:
# 4.265595386931401e-05
# Fitness generation number 1:
# 4.368701955475971e-05
# Fitness generation number 2:
# 4.441268607852297e-05
# Fitness generation number 3:
# 4.441268607852297e-05
# Fitness generation number 4:
# 4.456003672846725e-05
# Fitness generation number 5:
# 4.456003672846725e-05
# Fitness generation number 6:
# 4.456003672846725e-05
# Fitness generation number 7:
# 5.036650011978601e-05
# Fitness generation number 8:
# 5.036650011978601e-05
# Fitness generation number 9:
# 5.036650011978601e-05
# Fitness generation number 10:
# 5.036650011978601e-05
# Fitness generation number 11:
# 5.036650011978601e-05
# Fitness generation number 12:
# 5.036650011978601e-05
# Fitness generation number 13:
# 5.036650011978601e-05
# Fitness generation number 14:
# 5.036650011978601e-05
# Fitness generation number 15:
# 5.036650011978601e-05
# Fitness generation number 16:
# 5.036650011978601e-05
# Fitness generation number 17:
# 5.036650011978601e-05
# Fitness generation number 18:
# 5.036650011978601e-05
# Fitness generation number 19:
# 5.036650011978601e-05
# Fitness generation number 20:
# 5.036650011978601e-05
# Fitness generation number 21:
# 5.036650011978601e-05
# Fitness generation number 22:
# 5.036650011978601e-05
# Fitness generation number 23:
# 5.036650011978601e-05
# Fitness generation number 24:
# 5.036650011978601e-05
# Fitness generation number 25:
# 5.036650011978601e-05
# Fitness generation number 26:
# 5.036650011978601e-05
# Fitness generation number 27:
# 5.036650011978601e-05
# Fitness generation number 28:
# 5.036650011978601e-05
# Fitness generation number 29:
# 5.036650011978601e-05
# Fitness generation number 30:
# 5.036650011978601e-05
# Fitness generation number 31:
# 5.036650011978601e-05
# Fitness generation number 32:
# 5.036650011978601e-05
# Fitness generation number 33:
# 5.1228722594703086e-05
# Fitness generation number 34:
# 5.1228722594703086e-05
# Fitness generation number 35:
# 5.1228722594703086e-05
# Fitness generation number 36:
# 5.1228722594703086e-05
# Fitness generation number 37:
# 5.1228722594703086e-05
# Fitness generation number 38:
# 5.1228722594703086e-05
# Fitness generation number 39:
# 5.1228722594703086e-05
# Fitness generation number 40:
# 5.1228722594703086e-05
# Fitness generation number 41:
# 5.1228722594703086e-05
# Fitness generation number 42:
# 5.1228722594703086e-05
# Fitness generation number 43:
# 5.1228722594703086e-05
# Fitness generation number 44:
# 5.1228722594703086e-05
# Fitness generation number 45:
# 5.1228722594703086e-05
# Fitness generation number 46:
# 5.1228722594703086e-05
# Fitness generation number 47:
# 5.1228722594703086e-05
# Fitness generation number 48:
# 5.1228722594703086e-05
# Fitness generation number 49:
# 5.1228722594703086e-05
# Fitness generation number 50:
# 5.1228722594703086e-05
# Fitness generation number 51:
# 5.1228722594703086e-05
# Fitness generation number 52:
# 5.1228722594703086e-05
# Fitness generation number 53:
# 5.1228722594703086e-05
# Fitness generation number 54:
# 5.1228722594703086e-05
# Fitness generation number 55:
# 5.1228722594703086e-05
# Fitness generation number 56:
# 5.1228722594703086e-05
# Fitness generation number 57:
# 5.1228722594703086e-05
# Fitness generation number 58:
# 5.1228722594703086e-05
# Fitness generation number 59:
# 5.1228722594703086e-05
# Fitness generation number 60:
# 5.1228722594703086e-05
# Fitness generation number 61:
# 5.1228722594703086e-05
# Fitness generation number 62:
# 5.1228722594703086e-05
# Fitness generation number 63:
# 5.1228722594703086e-05
# Fitness generation number 64:
# 5.1228722594703086e-05
# Fitness generation number 65:
# 5.1228722594703086e-05
# Fitness generation number 66:
# 5.1228722594703086e-05
# Fitness generation number 67:
# 5.1228722594703086e-05
# Fitness generation number 68:
# 5.1228722594703086e-05
# Fitness generation number 69:
# 5.1228722594703086e-05
# Fitness generation number 70:
# 5.1228722594703086e-05
# Fitness generation number 71:
# 5.1228722594703086e-05
# Fitness generation number 72:
# 5.1228722594703086e-05
# Fitness generation number 73:
# 5.1228722594703086e-05
# Fitness generation number 74:
# 5.1228722594703086e-05
# Fitness generation number 75:
# 5.1228722594703086e-05
# Fitness generation number 76:
# 5.1228722594703086e-05
# Fitness generation number 77:
# 5.1228722594703086e-05
# Fitness generation number 78:
# 5.1228722594703086e-05
# Fitness generation number 79:
# 5.1228722594703086e-05
# Fitness generation number 80:
# 5.1228722594703086e-05
# Fitness generation number 81:
# 5.1228722594703086e-05
# Fitness generation number 82:
# 5.1228722594703086e-05
# Fitness generation number 83:
# 5.1228722594703086e-05
# Fitness generation number 84:
# 5.1228722594703086e-05
# Fitness generation number 85:
# 5.1228722594703086e-05
# Fitness generation number 86:
# 5.1228722594703086e-05
# Fitness generation number 87:
# 5.1228722594703086e-05
# Fitness generation number 88:
# 5.1228722594703086e-05
# Fitness generation number 89:
# 5.1228722594703086e-05
# Fitness generation number 90:
# 5.1228722594703086e-05
# Fitness generation number 91:
# 5.1228722594703086e-05
# Fitness generation number 92:
# 5.1228722594703086e-05
# Fitness generation number 93:
# 5.1228722594703086e-05
# Fitness generation number 94:
# 5.1228722594703086e-05
# Fitness generation number 95:
# 5.1228722594703086e-05
# Fitness generation number 96:
# 5.1228722594703086e-05
# Fitness generation number 97:
# 5.1228722594703086e-05
# Fitness generation number 98:
# 5.1228722594703086e-05
# Fitness generation number 99:
# 5.1228722594703086e-05
# Fitness generation number 100:
# 5.1228722594703086e-05
# Fitness generation number 101:
# 5.1228722594703086e-05
# Fitness generation number 102:
# 5.1228722594703086e-05
# Fitness generation number 103:
# 5.1228722594703086e-05
# Fitness generation number 104:
# 5.1228722594703086e-05
# Fitness generation number 105:
# 5.1228722594703086e-05
# Fitness generation number 106:
# 5.1228722594703086e-05
# Fitness generation number 107:
# 5.1228722594703086e-05
# Fitness generation number 108:
# 5.1228722594703086e-05
# Fitness generation number 109:
# 5.1228722594703086e-05
# Fitness generation number 110:
# 5.1228722594703086e-05
# Fitness generation number 111:
# 5.1228722594703086e-05
# Fitness generation number 112:
# 5.1228722594703086e-05
# Fitness generation number 113:
# 5.1228722594703086e-05
# Fitness generation number 114:
# 5.1228722594703086e-05
# Fitness generation number 115:
# 5.1228722594703086e-05
# Fitness generation number 116:
# 5.1228722594703086e-05
# Fitness generation number 117:
# 5.1228722594703086e-05
# Fitness generation number 118:
# 5.1228722594703086e-05
# Fitness generation number 119:
# 5.1228722594703086e-05
# Fitness generation number 120:
# 5.1228722594703086e-05
# Fitness generation number 121:
# 5.1228722594703086e-05
# Fitness generation number 122:
# 5.1228722594703086e-05
# Fitness generation number 123:
# 5.1228722594703086e-05
# Fitness generation number 124:
# 5.1228722594703086e-05
# Fitness generation number 125:
# 5.1228722594703086e-05
# Fitness generation number 126:
# 5.1228722594703086e-05
# Fitness generation number 127:
# 5.1228722594703086e-05
# Fitness generation number 128:
# 5.1228722594703086e-05
# Fitness generation number 129:
# 5.1228722594703086e-05
# Fitness generation number 130:
# 5.1228722594703086e-05
# Fitness generation number 131:
# 5.1228722594703086e-05
# Fitness generation number 132:
# 5.1228722594703086e-05
# Fitness generation number 133:
# 5.1228722594703086e-05
# Fitness generation number 134:
# 5.1228722594703086e-05
# Fitness generation number 135:
# 5.1228722594703086e-05
# Fitness generation number 136:
# 5.1228722594703086e-05
# Fitness generation number 137:
# 5.1228722594703086e-05
# Fitness generation number 138:
# 5.1228722594703086e-05
# Fitness generation number 139:
# 5.1228722594703086e-05
# Fitness generation number 140:
# 5.1228722594703086e-05
# Fitness generation number 141:
# 5.1228722594703086e-05
# Fitness generation number 142:
# 5.1228722594703086e-05
# Fitness generation number 143:
# 5.1228722594703086e-05
# Fitness generation number 144:
# 5.1228722594703086e-05
# Fitness generation number 145:
# 5.1228722594703086e-05
# Fitness generation number 146:
# 5.1228722594703086e-05
# Fitness generation number 147:
# 5.1228722594703086e-05
# Fitness generation number 148:
# 5.1228722594703086e-05
# Fitness generation number 149:
# 5.1228722594703086e-05
# Fitness generation number 150:
# 5.1228722594703086e-05
# Fitness generation number 151:
# 5.1228722594703086e-05
# Fitness generation number 152:
# 5.1228722594703086e-05
# Fitness generation number 153:
# 5.1228722594703086e-05
# Fitness generation number 154:
# 5.1228722594703086e-05
# Fitness generation number 155:
# 5.1228722594703086e-05
# Fitness generation number 156:
# 5.1228722594703086e-05
# Fitness generation number 157:
# 5.1228722594703086e-05
# Fitness generation number 158:
# 5.1228722594703086e-05
# Fitness generation number 159:
# 5.1228722594703086e-05
# Fitness generation number 160:
# 5.1228722594703086e-05
# Fitness generation number 161:
# 5.1228722594703086e-05
# Fitness generation number 162:
# 5.1228722594703086e-05
# Fitness generation number 163:
# 5.1228722594703086e-05
# Fitness generation number 164:
# 5.1228722594703086e-05
# Fitness generation number 165:
# 5.1228722594703086e-05
# Fitness generation number 166:
# 5.1228722594703086e-05
# Fitness generation number 167:
# 5.1228722594703086e-05
# Fitness generation number 168:
# 5.1228722594703086e-05
# Fitness generation number 169:
# 5.1228722594703086e-05
# Fitness generation number 170:
# 5.1228722594703086e-05
# Fitness generation number 171:
# 5.1228722594703086e-05
# Fitness generation number 172:
# 5.1228722594703086e-05
# Fitness generation number 173:
# 5.1228722594703086e-05
# Fitness generation number 174:
# 5.1228722594703086e-05
# Fitness generation number 175:
# 5.1228722594703086e-05
# Fitness generation number 176:
# 5.1228722594703086e-05
# Fitness generation number 177:
# 5.1228722594703086e-05
# Fitness generation number 178:
# 5.1228722594703086e-05
# Fitness generation number 179:
# 5.1228722594703086e-05
# Fitness generation number 180:
# 5.1228722594703086e-05
# Fitness generation number 181:
# 5.1228722594703086e-05
# Fitness generation number 182:
# 5.1228722594703086e-05
# Fitness generation number 183:
# 5.1228722594703086e-05
# Fitness generation number 184:
# 5.1228722594703086e-05
# Fitness generation number 185:
# 5.1228722594703086e-05
# Fitness generation number 186:
# 5.1228722594703086e-05
# Fitness generation number 187:
# 5.1228722594703086e-05
# Fitness generation number 188:
# 5.1228722594703086e-05
# Fitness generation number 189:
# 5.1228722594703086e-05
# Fitness generation number 190:
# 5.1228722594703086e-05
# Fitness generation number 191:
# 5.1228722594703086e-05
# Fitness generation number 192:
# 5.1228722594703086e-05
# Fitness generation number 193:
# 5.1228722594703086e-05
# Fitness generation number 194:
# 5.1228722594703086e-05
# Fitness generation number 195:
# 5.1228722594703086e-05
# Fitness generation number 196:
# 5.1228722594703086e-05
# Fitness generation number 197:
# 5.1228722594703086e-05
# Fitness generation number 198:
# 5.1228722594703086e-05
# Fitness generation number 199:
# 5.1228722594703086e-05
# Fitness generation number 200:
# 5.1228722594703086e-05
# Fitness generation number 201:
# 5.1228722594703086e-05
# Fitness generation number 202:
# 5.1228722594703086e-05
# Fitness generation number 203:
# 5.1228722594703086e-05
# Fitness generation number 204:
# 5.1228722594703086e-05
# Fitness generation number 205:
# 5.1228722594703086e-05
# Fitness generation number 206:
# 5.1228722594703086e-05
# Fitness generation number 207:
# 5.1228722594703086e-05
# Fitness generation number 208:
# 5.1228722594703086e-05
# Fitness generation number 209:
# 5.1228722594703086e-05
# Fitness generation number 210:
# 5.1228722594703086e-05
# Fitness generation number 211:
# 5.1228722594703086e-05
# Fitness generation number 212:
# 5.1228722594703086e-05
# Fitness generation number 213:
# 5.1228722594703086e-05
# Fitness generation number 214:
# 5.1228722594703086e-05
# Fitness generation number 215:
# 5.1228722594703086e-05
# Fitness generation number 216:
# 5.1228722594703086e-05
# Fitness generation number 217:
# 5.1228722594703086e-05
# Fitness generation number 218:
# 5.1228722594703086e-05
# Fitness generation number 219:
# 5.1228722594703086e-05
# Fitness generation number 220:
# 5.1228722594703086e-05
# Fitness generation number 221:
# 5.1228722594703086e-05
# Fitness generation number 222:
# 5.1228722594703086e-05
# Fitness generation number 223:
# 5.1228722594703086e-05
# Fitness generation number 224:
# 5.1228722594703086e-05
# Fitness generation number 225:
# 5.1228722594703086e-05
# Fitness generation number 226:
# 5.1228722594703086e-05
# Fitness generation number 227:
# 5.1228722594703086e-05
# Fitness generation number 228:
# 5.1228722594703086e-05
# Fitness generation number 229:
# 5.1228722594703086e-05
# Fitness generation number 230:
# 5.1228722594703086e-05
# Fitness generation number 231:
# 5.1228722594703086e-05
# Fitness generation number 232:
# 5.1228722594703086e-05
# Fitness generation number 233:
# 5.1228722594703086e-05
# Fitness generation number 234:
# 5.1228722594703086e-05
# Fitness generation number 235:
# 5.1228722594703086e-05
# Fitness generation number 236:
# 5.1228722594703086e-05
# Fitness generation number 237:
# 5.1228722594703086e-05
# Fitness generation number 238:
# 5.1228722594703086e-05
# Fitness generation number 239:
# 5.1228722594703086e-05
# Fitness generation number 240:
# 5.1228722594703086e-05
# Fitness generation number 241:
# 5.1228722594703086e-05
# Fitness generation number 242:
# 5.1228722594703086e-05
# Fitness generation number 243:
# 5.1228722594703086e-05
# Fitness generation number 244:
# 5.1228722594703086e-05
# Fitness generation number 245:
# 5.1228722594703086e-05
# Fitness generation number 246:
# 5.1228722594703086e-05
# Fitness generation number 247:
# 5.1228722594703086e-05
# Fitness generation number 248:
# 5.1228722594703086e-05
# Fitness generation number 249:
# 5.1228722594703086e-05
# Fitness generation number 250:
# 5.1228722594703086e-05
# Fitness generation number 251:
# 5.1228722594703086e-05
# Fitness generation number 252:
# 5.1228722594703086e-05
# Fitness generation number 253:
# 5.1228722594703086e-05
# Fitness generation number 254:
# 5.1228722594703086e-05
# Fitness generation number 255:
# 5.1228722594703086e-05
# Fitness generation number 256:
# 5.1228722594703086e-05
# Fitness generation number 257:
# 5.1228722594703086e-05
# Fitness generation number 258:
# 5.1228722594703086e-05
# Fitness generation number 259:
# 5.1228722594703086e-05
# Fitness generation number 260:
# 5.1228722594703086e-05
# Fitness generation number 261:
# 5.1228722594703086e-05
# Fitness generation number 262:
# 5.1228722594703086e-05
# Fitness generation number 263:
# 5.1228722594703086e-05
# Fitness generation number 264:
# 5.1228722594703086e-05
# Fitness generation number 265:
# 5.1228722594703086e-05
# Fitness generation number 266:
# 5.1228722594703086e-05
# Fitness generation number 267:
# 5.1228722594703086e-05
# Fitness generation number 268:
# 5.1228722594703086e-05
# Fitness generation number 269:
# 5.1228722594703086e-05
# Fitness generation number 270:
# 5.1228722594703086e-05
# Fitness generation number 271:
# 5.1228722594703086e-05
# Fitness generation number 272:
# 5.1228722594703086e-05
# Fitness generation number 273:
# 5.1228722594703086e-05
# Fitness generation number 274:
# 5.1228722594703086e-05
# Fitness generation number 275:
# 5.1228722594703086e-05
# Fitness generation number 276:
# 5.1228722594703086e-05
# Fitness generation number 277:
# 5.1228722594703086e-05
# Fitness generation number 278:
# 5.1228722594703086e-05
# Fitness generation number 279:
# 5.1228722594703086e-05
# Fitness generation number 280:
# 5.1228722594703086e-05
# Fitness generation number 281:
# 5.1228722594703086e-05
# Fitness generation number 282:
# 5.1228722594703086e-05
# Fitness generation number 283:
# 5.1228722594703086e-05
# Fitness generation number 284:
# 5.1228722594703086e-05
# Fitness generation number 285:
# 5.1228722594703086e-05
# Fitness generation number 286:
# 5.1228722594703086e-05
# Fitness generation number 287:
# 5.1228722594703086e-05
# Fitness generation number 288:
# 5.1228722594703086e-05
# Fitness generation number 289:
# 5.1228722594703086e-05
# Fitness generation number 290:
# 5.1228722594703086e-05
# Fitness generation number 291:
# 5.1228722594703086e-05
# Fitness generation number 292:
# 5.1228722594703086e-05
# Fitness generation number 293:
# 5.1228722594703086e-05
# Fitness generation number 294:
# 5.1228722594703086e-05
# Fitness generation number 295:
# 5.1228722594703086e-05
# Fitness generation number 296:
# 5.1228722594703086e-05
# Fitness generation number 297:
# 5.1228722594703086e-05
# Fitness generation number 298:
# 5.1228722594703086e-05
# Fitness generation number 299:
# 5.1228722594703086e-05
# Fitness generation number 300:
# 5.1228722594703086e-05
# Fitness generation number 301:
# 5.1228722594703086e-05
# Fitness generation number 302:
# 5.1228722594703086e-05
# Fitness generation number 303:
# 5.1228722594703086e-05
# Fitness generation number 304:
# 5.1228722594703086e-05
# Fitness generation number 305:
# 5.1228722594703086e-05
# Fitness generation number 306:
# 5.1228722594703086e-05
# Fitness generation number 307:
# 5.1228722594703086e-05
# Fitness generation number 308:
# 5.1228722594703086e-05
# Fitness generation number 309:
# 5.1228722594703086e-05
# Fitness generation number 310:
# 5.1228722594703086e-05
# Fitness generation number 311:
# 5.1228722594703086e-05
# Fitness generation number 312:
# 5.1228722594703086e-05
# Fitness generation number 313:
# 5.1228722594703086e-05
# Fitness generation number 314:
# 5.1228722594703086e-05
# Fitness generation number 315:
# 5.1228722594703086e-05
# Fitness generation number 316:
# 5.1228722594703086e-05
# Fitness generation number 317:
# 5.1228722594703086e-05
# Fitness generation number 318:
# 5.1228722594703086e-05
# Fitness generation number 319:
# 5.1228722594703086e-05
# Fitness generation number 320:
# 5.1228722594703086e-05
# Fitness generation number 321:
# 5.1228722594703086e-05
# Fitness generation number 322:
# 5.1228722594703086e-05
# Fitness generation number 323:
# 5.1228722594703086e-05
# Fitness generation number 324:
# 5.1228722594703086e-05
# Fitness generation number 325:
# 5.1228722594703086e-05
# Fitness generation number 326:
# 5.1228722594703086e-05
# Fitness generation number 327:
# 5.1228722594703086e-05
# Fitness generation number 328:
# 5.1228722594703086e-05
# Fitness generation number 329:
# 5.1228722594703086e-05
# Fitness generation number 330:
# 5.1228722594703086e-05
# Fitness generation number 331:
# 5.1228722594703086e-05
# Fitness generation number 332:
# 5.1228722594703086e-05
# Fitness generation number 333:
# 5.1228722594703086e-05
# Fitness generation number 334:
# 5.1228722594703086e-05
# Fitness generation number 335:
# 5.1228722594703086e-05
# Fitness generation number 336:
# 5.1228722594703086e-05
# Fitness generation number 337:
# 5.1228722594703086e-05
# Fitness generation number 338:
# 5.1228722594703086e-05
# Fitness generation number 339:
# 5.1228722594703086e-05
# Fitness generation number 340:
# 5.1228722594703086e-05
# Fitness generation number 341:
# 5.1228722594703086e-05
# Fitness generation number 342:
# 5.1228722594703086e-05
# Fitness generation number 343:
# 5.1228722594703086e-05
# Fitness generation number 344:
# 5.1228722594703086e-05
# Fitness generation number 345:
# 5.1228722594703086e-05
# Fitness generation number 346:
# 5.1228722594703086e-05
# Fitness generation number 347:
# 5.1228722594703086e-05
# Fitness generation number 348:
# 5.1228722594703086e-05
# Fitness generation number 349:
# 5.1228722594703086e-05
# Fitness generation number 350:
# 5.1228722594703086e-05
# Fitness generation number 351:
# 5.1228722594703086e-05
# Fitness generation number 352:
# 5.1228722594703086e-05
# Fitness generation number 353:
# 5.1228722594703086e-05
# Fitness generation number 354:
# 5.1228722594703086e-05
# Fitness generation number 355:
# 5.1228722594703086e-05
# Fitness generation number 356:
# 5.1228722594703086e-05
# Fitness generation number 357:
# 5.1228722594703086e-05
# Fitness generation number 358:
# 5.1228722594703086e-05
# Fitness generation number 359:
# 5.1228722594703086e-05
# Fitness generation number 360:
# 5.1228722594703086e-05
# Fitness generation number 361:
# 5.1228722594703086e-05
# Fitness generation number 362:
# 5.1228722594703086e-05
# Fitness generation number 363:
# 5.1228722594703086e-05
# Fitness generation number 364:
# 5.1228722594703086e-05
# Fitness generation number 365:
# 5.1228722594703086e-05
# Fitness generation number 366:
# 5.1228722594703086e-05
# Fitness generation number 367:
# 5.1228722594703086e-05
# Fitness generation number 368:
# 5.1228722594703086e-05
# Fitness generation number 369:
# 5.1228722594703086e-05
# Fitness generation number 370:
# 5.1228722594703086e-05
# Fitness generation number 371:
# 5.1228722594703086e-05
# Fitness generation number 372:
# 5.1228722594703086e-05
# Fitness generation number 373:
# 5.1228722594703086e-05
# Fitness generation number 374:
# 5.1228722594703086e-05
# Fitness generation number 375:
# 5.1228722594703086e-05
# Fitness generation number 376:
# 5.1228722594703086e-05
# Fitness generation number 377:
# 5.1228722594703086e-05
# Fitness generation number 378:
# 5.1228722594703086e-05
# Fitness generation number 379:
# 5.1228722594703086e-05
# Fitness generation number 380:
# 5.1228722594703086e-05
# Fitness generation number 381:
# 5.1228722594703086e-05
# Fitness generation number 382:
# 5.1228722594703086e-05
# Fitness generation number 383:
# 5.1228722594703086e-05
# Fitness generation number 384:
# 5.1228722594703086e-05
# Fitness generation number 385:
# 5.1228722594703086e-05
# Fitness generation number 386:
# 5.1228722594703086e-05
# Fitness generation number 387:
# 5.1228722594703086e-05
# Fitness generation number 388:
# 5.1228722594703086e-05
# Fitness generation number 389:
# 5.1228722594703086e-05
# Fitness generation number 390:
# 5.1228722594703086e-05
# Fitness generation number 391:
# 5.1228722594703086e-05
# Fitness generation number 392:
# 5.1228722594703086e-05
# Fitness generation number 393:
# 5.1228722594703086e-05
# Fitness generation number 394:
# 5.1228722594703086e-05
# Fitness generation number 395:
# 5.1228722594703086e-05
# Fitness generation number 396:
# 5.1228722594703086e-05
# Fitness generation number 397:
# 5.1228722594703086e-05
# Fitness generation number 398:
# 5.1228722594703086e-05
# Fitness generation number 399:
# 5.1228722594703086e-05
# Fitness generation number 400:
# 5.1228722594703086e-05
# Fitness generation number 401:
# 5.1228722594703086e-05
# Fitness generation number 402:
# 5.1228722594703086e-05
# Fitness generation number 403:
# 5.1228722594703086e-05
# Fitness generation number 404:
# 5.1228722594703086e-05
# Fitness generation number 405:
# 5.1228722594703086e-05
# Fitness generation number 406:
# 5.1228722594703086e-05
# Fitness generation number 407:
# 5.1228722594703086e-05
# Fitness generation number 408:
# 5.1228722594703086e-05
# Fitness generation number 409:
# 5.1228722594703086e-05
# Fitness generation number 410:
# 5.1228722594703086e-05
# Fitness generation number 411:
# 5.1228722594703086e-05
# Fitness generation number 412:
# 5.1228722594703086e-05
# Fitness generation number 413:
# 5.1228722594703086e-05
# Fitness generation number 414:
# 5.1228722594703086e-05
# Fitness generation number 415:
# 5.1228722594703086e-05
# Fitness generation number 416:
# 5.1228722594703086e-05
# Fitness generation number 417:
# 5.1228722594703086e-05
# Fitness generation number 418:
# 5.1228722594703086e-05
# Fitness generation number 419:
# 5.1228722594703086e-05
# Fitness generation number 420:
# 5.1228722594703086e-05
# Fitness generation number 421:
# 5.1228722594703086e-05
# Fitness generation number 422:
# 5.1228722594703086e-05
# Fitness generation number 423:
# 5.1228722594703086e-05
# Fitness generation number 424:
# 5.1228722594703086e-05
# Fitness generation number 425:
# 5.1228722594703086e-05
# Fitness generation number 426:
# 5.1228722594703086e-05
# Fitness generation number 427:
# 5.1228722594703086e-05
# Fitness generation number 428:
# 5.1228722594703086e-05
# Fitness generation number 429:
# 5.1228722594703086e-05
# Fitness generation number 430:
# 5.1228722594703086e-05
# Fitness generation number 431:
# 5.1228722594703086e-05
# Fitness generation number 432:
# 5.1228722594703086e-05
# Fitness generation number 433:
# 5.1228722594703086e-05
# Fitness generation number 434:
# 5.1228722594703086e-05
# Fitness generation number 435:
# 5.1228722594703086e-05
# Fitness generation number 436:
# 5.1228722594703086e-05
# Fitness generation number 437:
# 5.1228722594703086e-05
# Fitness generation number 438:
# 5.1228722594703086e-05
# Fitness generation number 439:
# 5.1228722594703086e-05
# Fitness generation number 440:
# 5.1228722594703086e-05
# Fitness generation number 441:
# 5.1228722594703086e-05
# Fitness generation number 442:
# 5.1228722594703086e-05
# Fitness generation number 443:
# 5.1228722594703086e-05
# Fitness generation number 444:
# 5.1228722594703086e-05
# Fitness generation number 445:
# 5.1228722594703086e-05
# Fitness generation number 446:
# 5.1228722594703086e-05
# Fitness generation number 447:
# 5.1228722594703086e-05
# Fitness generation number 448:
# 5.1228722594703086e-05
# Fitness generation number 449:
# 5.1228722594703086e-05
# Fitness generation number 450:
# 5.1228722594703086e-05
# Fitness generation number 451:
# 5.1228722594703086e-05
# Fitness generation number 452:
# 5.1228722594703086e-05
# Fitness generation number 453:
# 5.1228722594703086e-05
# Fitness generation number 454:
# 5.1228722594703086e-05
# Fitness generation number 455:
# 5.1228722594703086e-05
# Fitness generation number 456:
# 5.1228722594703086e-05
# Fitness generation number 457:
# 5.1228722594703086e-05
# Fitness generation number 458:
# 5.1228722594703086e-05
# Fitness generation number 459:
# 5.1228722594703086e-05
# Fitness generation number 460:
# 5.1228722594703086e-05
# Fitness generation number 461:
# 5.1228722594703086e-05
# Fitness generation number 462:
# 5.1228722594703086e-05
# Fitness generation number 463:
# 5.1228722594703086e-05
# Fitness generation number 464:
# 5.1228722594703086e-05
# Fitness generation number 465:
# 5.1228722594703086e-05
# Fitness generation number 466:
# 5.1228722594703086e-05
# Fitness generation number 467:
# 5.1228722594703086e-05
# Fitness generation number 468:
# 5.1228722594703086e-05
# Fitness generation number 469:
# 5.1228722594703086e-05
# Fitness generation number 470:
# 5.1228722594703086e-05
# Fitness generation number 471:
# 5.1228722594703086e-05
# Fitness generation number 472:
# 5.1228722594703086e-05
# Fitness generation number 473:
# 5.1228722594703086e-05
# Fitness generation number 474:
# 5.1228722594703086e-05
# Fitness generation number 475:
# 5.1228722594703086e-05
# Fitness generation number 476:
# 5.1228722594703086e-05
# Fitness generation number 477:
# 5.1228722594703086e-05
# Fitness generation number 478:
# 5.1228722594703086e-05
# Fitness generation number 479:
# 5.1228722594703086e-05
# Fitness generation number 480:
# 5.1228722594703086e-05
# Fitness generation number 481:
# 5.1228722594703086e-05
# Fitness generation number 482:
# 5.1228722594703086e-05
# Fitness generation number 483:
# 5.1228722594703086e-05
# Fitness generation number 484:
# 5.1228722594703086e-05
# Fitness generation number 485:
# 5.1228722594703086e-05
# Fitness generation number 486:
# 5.1228722594703086e-05
# Fitness generation number 487:
# 5.1228722594703086e-05
# Fitness generation number 488:
# 5.1228722594703086e-05
# Fitness generation number 489:
# 5.1228722594703086e-05
# Fitness generation number 490:
# 5.1228722594703086e-05
# Fitness generation number 491:
# 5.1228722594703086e-05
# Fitness generation number 492:
# 5.1228722594703086e-05
# Fitness generation number 493:
# 5.1228722594703086e-05
# Fitness generation number 494:
# 5.1228722594703086e-05
# Fitness generation number 495:
# 5.1228722594703086e-05
# Fitness generation number 496:
# 5.1228722594703086e-05
# Fitness generation number 497:
# 5.1228722594703086e-05
# Fitness generation number 498:
# 5.1228722594703086e-05
# Fitness generation number 499:
# 5.1228722594703086e-05
# Final fitness:
# 5.1228722594703086e-05
# Final Minimum total traveling distance:
# 19520.299342841652
# Elite:
# ([7, 9, 8, 1, 3, 2, 4, 10, 5, 6], 5.1228722594703086e-05)
# Elite has repeated cities:
# False

# %% [markdown]
# Create the plots

# %%
# Assuming reduced_nodes is a dictionary containing node coordinates

# Create a graph and add nodes
G = nx.Graph()
G.add_nodes_from(reduced_nodes.keys())

# Draw the nodes
pos = {node: (reduced_nodes[node][0], reduced_nodes[node][1]) for node in reduced_nodes}
nx.draw(G, pos, node_color='black', with_labels=False, node_size=100)

# Draw the circular path stored in tsp.elite[0]
elite_path = tsp.elite[0]  # Assuming tsp.elite[0] contains the circular path

# Add edges for the circular path
for i in range(len(elite_path) - 1):
    G.add_edge(elite_path[i], elite_path[i + 1])

# Connect the last and first nodes to complete the circular path
G.add_edge(elite_path[-1], elite_path[0])

# Draw the edges
nx.draw_networkx_edges(G, pos, edgelist=[(elite_path[i], elite_path[i + 1]) for i in range(len(elite_path) - 1)], edge_color='blue', width=2)
nx.draw_networkx_edges(G, pos, edgelist=[(elite_path[-1], elite_path[0])], edge_color='blue', width=2)

plt.title('Reduced TSP to ' + str(N) +' Cities with Circular Path')
plt.show()


plt.plot(range(1, len(tsp.evolution_data) + 1), tsp.evolution_data, linestyle='-')
plt.title('Evolution of Minimum Total Traveling Distance')
plt.xlabel('Generation')
plt.ylabel('Minimum Total Traveling Distance')
plt.show()
